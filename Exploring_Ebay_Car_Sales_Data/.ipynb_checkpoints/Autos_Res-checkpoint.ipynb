# %%
import pandas as pd
import numpy as np

autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
new_columns = autos.copy()

new_columns.rename({'yearOfRegistration':'registration_year'}, axis = 1, inplace = True)
new_columns.rename({'monthOfRegistration':'registration_month'}, axis = 1, inplace = True)
new_columns.rename({'notRepairedDamage':'unrepaired_damage'}, axis = 1, inplace = True)
new_columns.rename({'dateCrawled':'date_crawled'}, axis = 1, inplace = True)
new_columns.rename({'offerType':'offer_type'}, axis = 1, inplace = True)
new_columns.rename({'vehicleType':'vehicle_type'}, axis = 1, inplace = True)
new_columns.rename({'powerPS':'power_ps'}, axis = 1, inplace = True)
new_columns.rename({'fuelType':'fuel_type'}, axis = 1, inplace = True)
new_columns.rename({'dateCreated':'date_created'}, axis = 1, inplace = True)
new_columns.rename({'nrOfPictures':'nr_of_pictures'}, axis = 1, inplace = True)
new_columns.rename({'postalCode':'postal_code'}, axis = 1, inplace = True)
new_columns.rename({'lastSeen':'last_seen'}, axis = 1, inplace = True)

# %%
new_columns
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.columns = new_columns.columns
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-30 17:37:35  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_ps  model  \
# ...

# %% [markdown]
# Seems like 'nr_of_pictures', 'offer_type' and 'seller' columns are candidates to be dropped, because these columns have mostly one value

# %%
autos = autos.drop(['nr_of_pictures', 'offer_type', 'seller'], axis=1)

# %% [markdown]
# Also columns 'price' and 'odometer' have numeric values stored as text, so we need to modificate these columns for a better analysis

# %%
autos['price'] = autos['price'].str.replace('$','').str.replace(',','').astype(int)

# %%
autos.rename({'price':'price_usd'}, axis = 1, inplace = True)
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos['odometer'].value_counts()
autos['odometer'] = autos['odometer'].str.replace('km','').str.replace(',','').astype(int)

# %%
autos['odometer'].value_counts()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer, dtype: int64

# %%
autos.rename({"odometer":"odometer_km"}, axis = 1, inplace = True)

# %%
autos['price_usd'].value_counts().sort_index()
# Out:
# 0           1421
# 1            156
# 2              3
# 3              1
# 5              2
# 8              1
# 9              1
# 10             7
# 11             2
# 12             3
# 13             2
# 14             1
# 15             2
# 17             3
# 18             1
# 20             4
# 25             5
# 29             1
# 30             7
# 35             1
# 40             6
# 45             4
# 47             1
# 49             4
# 50            49
# 55             2
# 59             1
# 60             9
# 65             5
# 66             1
#             ...
# 151990         1
# 155000         1
# 163500         1
# 163991         1
# 169000         1
# 169999         1
# 175000         1
# 180000         1
# 190000         1
# 194000         1
# 197000         1
# 198000         1
# 220000         1
# 250000         1
# 259000         1
# 265000         1
# 295000         1
# 299000         1
# 345000         1
# 350000         1
# 999990         1
# ...

# %% [markdown]
# Let's remove unrealistic(more than 500,000$) and null values of price_usd from the dataset

# %%
autos = autos[autos['price_usd'].between(1, 500000)]
autos['price_usd'].value_counts().sort_index()
# Out:
# 1         156
# 2           3
# 3           1
# 5           2
# 8           1
# 9           1
# 10          7
# 11          2
# 12          3
# 13          2
# 14          1
# 15          2
# 17          3
# 18          1
# 20          4
# 25          5
# 29          1
# 30          7
# 35          1
# 40          6
# 45          4
# 47          1
# 49          4
# 50         49
# 55          2
# 59          1
# 60          9
# 65          5
# 66          1
# 70         10
#          ...
# 119500      1
# 119900      1
# 120000      2
# 128000      1
# 129000      1
# 130000      1
# 135000      1
# 137999      1
# 139997      1
# 145000      1
# 151990      1
# 155000      1
# 163500      1
# 163991      1
# 169000      1
# 169999      1
# 175000      1
# 180000      1
# 190000      1
# 194000      1
# 197000      1
# 198000      1
# 220000      1
# 250000      1
# 259000      1
# 265000      1
# 295000      1
# 299000      1
# 345000      1
# 350000      1
# ...

# %%
autos['odometer_km'].value_counts()
# Out:
# 150000    31414
# 125000     5057
# 100000     2115
# 90000      1734
# 80000      1415
# 70000      1217
# 60000      1155
# 50000      1012
# 5000        836
# 40000       815
# 30000       780
# 20000       762
# 10000       253
# Name: odometer_km, dtype: int64

# %% [markdown]
# As we can see, there are no strange outliers in the column 'odometer_km'.
# Also, high values here are more common than low.

# %%
autos['date_crawled'].str[0:10].value_counts(normalize = True, dropna = False).sort_index()
# Out:
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: date_crawled, dtype: float64

# %%
autos['date_crawled'].str[0:10].value_counts(normalize = True, dropna = False).sort_values()
# Out:
# 2016-04-07    0.001400
# 2016-04-06    0.003171
# 2016-03-18    0.012911
# 2016-04-05    0.013096
# 2016-03-06    0.014043
# 2016-03-13    0.015670
# 2016-03-05    0.025327
# 2016-03-24    0.029342
# 2016-03-16    0.029610
# 2016-03-27    0.031092
# 2016-03-25    0.031607
# 2016-03-17    0.031628
# 2016-03-31    0.031834
# 2016-03-10    0.032184
# 2016-03-26    0.032204
# 2016-03-23    0.032225
# 2016-03-11    0.032575
# 2016-03-22    0.032987
# 2016-03-09    0.033090
# 2016-03-08    0.033296
# 2016-03-30    0.033687
# 2016-04-01    0.033687
# 2016-03-29    0.034099
# 2016-03-15    0.034284
# 2016-03-19    0.034778
# 2016-03-28    0.034860
# 2016-04-02    0.035478
# 2016-03-07    0.036014
# 2016-04-04    0.036487
# 2016-03-14    0.036549
# 2016-03-12    0.036920
# 2016-03-21    0.037373
# 2016-03-20    0.037887
# 2016-04-03    0.038608
# Name: date_crawled, dtype: float64

# %% [markdown]
# As we can see, the distribution of listings crawled on each day is roughly uniform.

# %%
autos['date_created'].str[0:10].value_counts(normalize = True, dropna = False).sort_index()
# Out:
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# 2015-12-05    0.000021
# 2015-12-30    0.000021
# 2016-01-03    0.000021
# 2016-01-07    0.000021
# 2016-01-10    0.000041
# 2016-01-13    0.000021
# 2016-01-14    0.000021
# 2016-01-16    0.000021
# 2016-01-22    0.000021
# 2016-01-27    0.000062
# 2016-01-29    0.000021
# 2016-02-01    0.000021
# 2016-02-02    0.000041
# 2016-02-05    0.000041
# 2016-02-07    0.000021
# 2016-02-08    0.000021
# 2016-02-09    0.000021
# 2016-02-11    0.000021
# 2016-02-12    0.000041
# 2016-02-14    0.000041
# 2016-02-16    0.000021
# 2016-02-17    0.000021
# 2016-02-18    0.000041
# 2016-02-19    0.000062
# 2016-02-20    0.000041
# 2016-02-21    0.000062
#                 ...
# 2016-03-09    0.033151
# 2016-03-10    0.031895
# 2016-03-11    0.032904
# 2016-03-12    0.036755
# 2016-03-13    0.017008
# 2016-03-14    0.035190
# 2016-03-15    0.034016
# 2016-03-16    0.030125
# 2016-03-17    0.031278
# ...

# %%
autos['date_created'].str[0:10].value_counts(normalize = True, dropna = False).sort_values()
# Out:
# 2015-11-10    0.000021
# 2016-02-22    0.000021
# 2015-08-10    0.000021
# 2016-01-29    0.000021
# 2016-02-09    0.000021
# 2016-01-22    0.000021
# 2016-02-11    0.000021
# 2016-01-14    0.000021
# 2015-12-30    0.000021
# 2016-02-16    0.000021
# 2015-12-05    0.000021
# 2016-02-17    0.000021
# 2016-02-08    0.000021
# 2016-01-16    0.000021
# 2015-06-11    0.000021
# 2016-02-07    0.000021
# 2016-01-03    0.000021
# 2016-02-01    0.000021
# 2016-01-07    0.000021
# 2015-09-09    0.000021
# 2016-01-13    0.000021
# 2016-02-02    0.000041
# 2016-02-05    0.000041
# 2016-02-26    0.000041
# 2016-01-10    0.000041
# 2016-02-20    0.000041
# 2016-02-14    0.000041
# 2016-02-12    0.000041
# 2016-02-24    0.000041
# 2016-02-18    0.000041
#                 ...
# 2016-03-06    0.015320
# 2016-03-13    0.017008
# 2016-03-05    0.022897
# 2016-03-24    0.029280
# 2016-03-16    0.030125
# 2016-03-27    0.030989
# 2016-03-17    0.031278
# 2016-03-25    0.031751
# 2016-03-31    0.031875
# ...

# %%
autos['last_seen'].str[0:10].value_counts(normalize = True, dropna = False).sort_index()
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-08    0.007413
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-12    0.023783
# 2016-03-13    0.008895
# 2016-03-14    0.012602
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-17    0.028086
# 2016-03-18    0.007351
# 2016-03-19    0.015834
# 2016-03-20    0.020653
# 2016-03-21    0.020632
# 2016-03-22    0.021373
# 2016-03-23    0.018532
# 2016-03-24    0.019767
# 2016-03-25    0.019211
# 2016-03-26    0.016802
# 2016-03-27    0.015649
# 2016-03-28    0.020859
# 2016-03-29    0.022341
# 2016-03-30    0.024771
# 2016-03-31    0.023783
# 2016-04-01    0.022794
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-04-04    0.024483
# 2016-04-05    0.124761
# 2016-04-06    0.221806
# 2016-04-07    0.131947
# Name: last_seen, dtype: float64

# %%
autos['date_created'].str[0:10].value_counts(normalize = True, dropna = False).sort_values()
# Out:
# 2015-11-10    0.000021
# 2016-02-22    0.000021
# 2015-08-10    0.000021
# 2016-01-29    0.000021
# 2016-02-09    0.000021
# 2016-01-22    0.000021
# 2016-02-11    0.000021
# 2016-01-14    0.000021
# 2015-12-30    0.000021
# 2016-02-16    0.000021
# 2015-12-05    0.000021
# 2016-02-17    0.000021
# 2016-02-08    0.000021
# 2016-01-16    0.000021
# 2015-06-11    0.000021
# 2016-02-07    0.000021
# 2016-01-03    0.000021
# 2016-02-01    0.000021
# 2016-01-07    0.000021
# 2015-09-09    0.000021
# 2016-01-13    0.000021
# 2016-02-02    0.000041
# 2016-02-05    0.000041
# 2016-02-26    0.000041
# 2016-01-10    0.000041
# 2016-02-20    0.000041
# 2016-02-14    0.000041
# 2016-02-12    0.000041
# 2016-02-24    0.000041
# 2016-02-18    0.000041
#                 ...
# 2016-03-06    0.015320
# 2016-03-13    0.017008
# 2016-03-05    0.022897
# 2016-03-24    0.029280
# 2016-03-16    0.030125
# 2016-03-27    0.030989
# 2016-03-17    0.031278
# 2016-03-25    0.031751
# 2016-03-31    0.031875
# ...

# %%
autos['last_seen'].str[0:10].value_counts(normalize = True, dropna = False).sort_index()
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-08    0.007413
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-12    0.023783
# 2016-03-13    0.008895
# 2016-03-14    0.012602
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-17    0.028086
# 2016-03-18    0.007351
# 2016-03-19    0.015834
# 2016-03-20    0.020653
# 2016-03-21    0.020632
# 2016-03-22    0.021373
# 2016-03-23    0.018532
# 2016-03-24    0.019767
# 2016-03-25    0.019211
# 2016-03-26    0.016802
# 2016-03-27    0.015649
# 2016-03-28    0.020859
# 2016-03-29    0.022341
# 2016-03-30    0.024771
# 2016-03-31    0.023783
# 2016-04-01    0.022794
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-04-04    0.024483
# 2016-04-05    0.124761
# 2016-04-06    0.221806
# 2016-04-07    0.131947
# Name: last_seen, dtype: float64

# %%
autos['last_seen'].str[0:10].value_counts(normalize = True, dropna = False).sort_values()
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-18    0.007351
# 2016-03-08    0.007413
# 2016-03-13    0.008895
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-14    0.012602
# 2016-03-27    0.015649
# 2016-03-19    0.015834
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-26    0.016802
# 2016-03-23    0.018532
# 2016-03-25    0.019211
# 2016-03-24    0.019767
# 2016-03-21    0.020632
# 2016-03-20    0.020653
# 2016-03-28    0.020859
# 2016-03-22    0.021373
# 2016-03-29    0.022341
# 2016-04-01    0.022794
# 2016-03-12    0.023783
# 2016-03-31    0.023783
# 2016-04-04    0.024483
# 2016-03-30    0.024771
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-03-17    0.028086
# 2016-04-05    0.124761
# 2016-04-07    0.131947
# 2016-04-06    0.221806
# Name: last_seen, dtype: float64

# %% [markdown]
# The last three days contain a disproportionate amount of 'last seen' values. Maybe this thing occured because of the crawling period ending.

# %%
autos['registration_year'].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# As we can see, 'registration year' contain some fake information - minimum and maximum registration year are incorrect.

# %% [markdown]
# Let's count the number of listings with cars that fall outside the 1900 - 2016 interval and try to remove those rows entirely

# %%
autos = autos[autos['registration_year'].between(1900, 2016)]

# %%
autos['registration_year'].value_counts(normalize=True).sort_index()
# Out:
# 1910    0.000107
# 1927    0.000021
# 1929    0.000021
# 1931    0.000021
# 1934    0.000043
# 1937    0.000086
# 1938    0.000021
# 1939    0.000021
# 1941    0.000043
# 1943    0.000021
# 1948    0.000021
# 1950    0.000064
# 1951    0.000043
# 1952    0.000021
# 1953    0.000021
# 1954    0.000043
# 1955    0.000043
# 1956    0.000086
# 1957    0.000043
# 1958    0.000086
# 1959    0.000129
# 1960    0.000493
# 1961    0.000129
# 1962    0.000086
# 1963    0.000171
# 1964    0.000257
# 1965    0.000364
# 1966    0.000471
# 1967    0.000557
# 1968    0.000557
#           ...
# 1987    0.001542
# 1988    0.002892
# 1989    0.003727
# 1990    0.007433
# 1991    0.007262
# 1992    0.007926
# 1993    0.009104
# 1994    0.013474
# 1995    0.026285
# 1996    0.029412
# 1997    0.041794
# 1998    0.050620
# 1999    0.062060
# 2000    0.067608
# 2001    0.056468
# 2002    0.053255
# 2003    0.057818
# 2004    0.057904
# 2005    0.062895
# 2006    0.057197
# 2007    0.048778
# ...

# %% [markdown]
# There are very small values before the years 1957-1959, so it seems like registration year of the cars is before 1957 may be incorrect.

# %% [markdown]
# Let's remove those rows too.

# %%
autos = autos[autos['registration_year'].between(1956, 2016)]

# %%
autos['registration_year'].value_counts(normalize=True).sort_index()
# Out:
# 1956    0.000086
# 1957    0.000043
# 1958    0.000086
# 1959    0.000129
# 1960    0.000493
# 1961    0.000129
# 1962    0.000086
# 1963    0.000171
# 1964    0.000257
# 1965    0.000364
# 1966    0.000472
# 1967    0.000557
# 1968    0.000557
# 1969    0.000407
# 1970    0.000815
# 1971    0.000557
# 1972    0.000707
# 1973    0.000493
# 1974    0.000514
# 1975    0.000386
# 1976    0.000450
# 1977    0.000472
# 1978    0.000943
# 1979    0.000729
# 1980    0.001822
# 1981    0.000600
# 1982    0.000879
# 1983    0.001093
# 1984    0.001093
# 1985    0.002036
#           ...
# 1987    0.001543
# 1988    0.002894
# 1989    0.003730
# 1990    0.007438
# 1991    0.007267
# 1992    0.007931
# 1993    0.009110
# 1994    0.013483
# 1995    0.026302
# 1996    0.029432
# 1997    0.041822
# 1998    0.050654
# 1999    0.062101
# 2000    0.067653
# 2001    0.056506
# 2002    0.053290
# 2003    0.057856
# 2004    0.057942
# 2005    0.062937
# 2006    0.057235
# 2007    0.048810
# ...

# %%
autos['brand'].value_counts(normalize=True).head(20)
# Out:
# volkswagen        0.211383
# bmw               0.110096
# opel              0.107588
# mercedes_benz     0.096442
# audi              0.086624
# ford              0.069861
# renault           0.047160
# peugeot           0.029861
# fiat              0.025659
# seat              0.018264
# skoda             0.016420
# nissan            0.015284
# mazda             0.015198
# smart             0.014169
# citroen           0.013998
# toyota            0.012712
# hyundai           0.010032
# sonstige_autos    0.009603
# volvo             0.009153
# mini              0.008767
# Name: brand, dtype: float64

# %%
brands = autos['brand'].value_counts(normalize=True)
common_brands = brands[brands>0.05].index
common_brands
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %% [markdown]
# I have chosen to aggregate common brands that have over a certain percentage of the total values (> 0.05)

# %%
brand_mean_prices = {}

for x in common_brands:
    temp_mean = autos.loc[autos['brand'] == x, 'price_usd'].mean()
    brand_mean_prices[x] = temp_mean.astype(int)

# %%
brand_mean_prices
# Out:
# {'volkswagen': 5398,
#  'bmw': 8332,
#  'opel': 2976,
#  'mercedes_benz': 8580,
#  'audi': 9336,
#  'ford': 3720}

# %% [markdown]
# Audi, Mercedes and BMW have the most expensive cars among the most common cars.
# Opel is the cheapest brand among the most common cars.

# %%
brand_mean_miles = {}

for x in common_brands:
    temp_mean = autos.loc[autos['brand'] == x, 'odometer_km'].mean()
    brand_mean_miles[x] = temp_mean.astype(int)

# %%
brand_mean_miles
# Out:
# {'volkswagen': 128710,
#  'bmw': 132597,
#  'opel': 129336,
#  'mercedes_benz': 130865,
#  'audi': 129157,
#  'ford': 124390}

# %%
price_series = pd.Series(brand_mean_prices)
miles_series = pd.Series(brand_mean_miles)

# %%
brand_df = pd.DataFrame(data=price_series, columns=['mean_price_usd'])

# %%
brand_df
# Out:
#                mean_price_usd
# volkswagen               5398
# bmw                      8332
# opel                     2976
# mercedes_benz            8580
# audi                     9336
# ford                     3720

# %%
brand_df['mean_mileage_km'] = miles_series

# %%
brand_df
# Out:
#                mean_price_usd  mean_mileage_km
# volkswagen               5398           128710
# bmw                      8332           132597
# opel                     2976           129336
# mercedes_benz            8580           130865
# audi                     9336           129157
# ford                     3720           124390

# %% [markdown]
# Now aggregate data about mean prices and mean mileage of the common brand cars is stored in a new dataframe.

# %% [markdown]
# And as we can see in this dataframe, the range of car mileages does not vary as much as the prices do by brand. However, the most expensive brands have a slightly bigger mileage.

# %% [markdown]
# ## Data cleaning next steps:
#     * Identify categorical data that uses german words, translate them and map the values to their english counterparts
#     * Convert the dates to be uniform numeric data, so "2016-03-21" becomes the integer 20160321.
#     * See if there are particular keywords in the name column that you can extract as new columns
# ## Analysis next steps:
#     * Find the most common brand/model combinations
#     * Split the odometer_km into groups, and use aggregation to see if average prices follows any patterns based on the milage.
#     * How much cheaper are cars with damage than their non-damaged counterparts?

# %%
autos.head(20)
# Out:
#            date_crawled                                               name  \
# 0   2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3   2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5   2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6   2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7   2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8   2016-03-22 16:51:34                                         Seat_Arosa
# 9   2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 11  2016-03-16 18:45:34                         Mercedes_A140_Motorschaden
# ...

# %% [markdown]
# Let's identify categorical data that uses german words, translate them and map the values to their english counterparts.
# There are some german words in 'vehicle type' column, so let's translate them.

# %%
tran_veh_dict = {
    'bus' : 'bus',
    'limousine' : 'limousine',
    'kleinwagen' : 'small car',
    'kombi' : 'estate car',
    'coupe' : 'coupe',
    'suv' : 'suv',
    'cabrio' : 'cabrio',
    'andere' : 'other',
}

# %%
autos['vehicle_type'].unique()
# Out:
# array(['bus', 'limousine', 'kleinwagen', 'kombi', nan, 'coupe', 'suv',
#        'cabrio', 'andere'], dtype=object)

# %%
autos['vehicle_type'] = autos['vehicle_type'].map(tran_veh_dict)

# %%
autos['vehicle_type'].unique()
# Out:
# array(['bus', 'limousine', 'small car', 'estate car', nan, 'coupe', 'suv',
#        'cabrio', 'other'], dtype=object)

# %% [markdown]
# Also words in the 'gearbox' and some other columns are german.

# %%
tran_gear_dict = {
    'manuell' : 'manual',
    'automatik' : 'automatic'
}

# %%
autos['gearbox'] = autos['gearbox'].map(tran_gear_dict)

# %%
autos['gearbox'].unique()
# Out:
# array(['manual', 'automatic', nan], dtype=object)

# %%
autos['fuel_type'].unique()
# Out:
# array(['lpg', 'benzin', 'diesel', nan, 'cng', 'hybrid', 'elektro',
#        'andere'], dtype=object)

# %%
tran_fuel_dict = {
    'lpg' : 'lpg',
    'benzin' : 'petrol',
    'diesel' : 'diesel',
    'cng' : 'cng',
    'hybrid' : 'hybrid',
    'elektro' : 'electro',
    'andere' : 'other'
}

# %%
autos['fuel_type'] = autos['fuel_type'].map(tran_fuel_dict)

# %%
autos.head(20)
# Out:
#            date_crawled                                               name  \
# 0   2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3   2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5   2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6   2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7   2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8   2016-03-22 16:51:34                                         Seat_Arosa
# 9   2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 11  2016-03-16 18:45:34                         Mercedes_A140_Motorschaden
# ...

# %%
tran_unrep_dict = {
    'nein' : 'none',
    'ja' : 'yes'
}

# %%
autos['unrepaired_damage'] = autos['unrepaired_damage'].map(tran_unrep_dict)

# %%
autos['unrepaired_damage'].unique()
# Out:
# array(['none', nan, 'yes'], dtype=object)

# %%
autos['last_seen'].value_counts()
# Out:
# 2016-04-07 06:17:27    8
# 2016-04-06 21:17:51    7
# 2016-04-07 03:16:17    7
# 2016-04-07 06:46:12    6
# 2016-04-05 16:44:47    6
# 2016-04-07 04:46:51    6
# 2016-04-06 19:16:38    6
# 2016-04-06 13:17:03    6
# 2016-04-06 02:17:26    6
# 2016-04-06 14:17:04    6
# 2016-04-07 05:16:17    6
# 2016-04-07 03:45:23    6
# 2016-04-06 02:16:12    6
# 2016-04-06 22:17:26    6
# 2016-04-06 14:44:55    6
# 2016-04-06 10:17:12    6
# 2016-04-06 20:48:27    6
# 2016-04-06 06:17:24    6
# 2016-04-06 08:44:19    6
# 2016-04-06 15:17:56    6
# 2016-04-06 07:46:11    6
# 2016-04-07 04:46:40    5
# 2016-04-06 16:17:59    5
# 2016-04-07 04:16:09    5
# 2016-04-06 11:16:02    5
# 2016-04-06 12:45:16    5
# 2016-04-06 05:15:21    5
# 2016-04-06 15:17:11    5
# 2016-04-06 06:16:52    5
# 2016-04-07 04:15:59    5
#                       ..
# 2016-03-17 08:44:14    1
# 2016-03-29 05:18:08    1
# 2016-04-07 03:16:10    1
# 2016-03-19 10:17:07    1
# 2016-03-13 04:46:34    1
# 2016-04-05 02:45:36    1
# ...

# %% [markdown]
# Now let's convert the dates to be uniform numeric data, so "2016-03-21" becomes the integer 20160321

# %%
import datetime as dt

# %% [markdown]
# This is a function to convert string date to int

# %%
def change_date(str):
    dt_temp = dt.datetime.strptime(str, '%Y-%m-%d %H:%M:%S')
    return int(dt_temp.strftime('%Y%m%d'))

# %% [markdown]
# Let's check this function

# %%
change_date('2016-03-20 10:49:13')
# Out:
# 20160320

# %% [markdown]
# Function to optimize changing date in each column

# %%
def change_date_col(str):
    col = autos[str]
    new_col = []
    
    for x in col:
        x = change_date(x)
        new_col.append(x)
    autos[str] = new_col

# %%
change_date_col('date_crawled')
change_date_col('date_created')
change_date_col('last_seen')

# %%
autos.head(5)
# Out:
#    date_crawled                                               name  price_usd  \
# 0      20160326                   Peugeot_807_160_NAVTECH_ON_BOARD       5000
# 1      20160404         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik       8500
# 2      20160326                         Volkswagen_Golf_1.6_United       8990
# 3      20160312  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...       4350
# 4      20160401  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...       1350
#
#     abtest vehicle_type  registration_year    gearbox  power_ps   model  \
# 0  control          bus               2004     manual       158  andere
# 1  control    limousine               1997  automatic       286     7er
# 2     test    limousine               2009     manual       102    golf
# 3  control    small car               2007  automatic        71  fortwo
# 4     test   estate car               2003     manual         0   focus
#
# ...

# %% [markdown]
# Now let's find the most common brand/model combinations

# %% [markdown]
# For this task I will create an extra column for a combination

# %%
autos['brand-model'] = autos['brand'] + ' '+ autos['model']

# %%
autos['brand-model'].head()
# Out:
# 0     peugeot andere
# 1            bmw 7er
# 2    volkswagen golf
# 3       smart fortwo
# 4         ford focus
# Name: brand-model, dtype: object

# %%
autos['brand-model'].value_counts().head(3)
# Out:
# volkswagen golf    3707
# bmw 3er            2615
# volkswagen polo    1609
# Name: brand-model, dtype: int64

# %% [markdown]
# As we can see, the most common brand-model combination is 'volkswagen golf'

# %%
autos['odometer_km'].value_counts()
# Out:
# 150000    30082
# 125000     4856
# 100000     2054
# 90000      1671
# 80000      1375
# 70000      1186
# 60000      1125
# 50000       992
# 40000       795
# 5000        773
# 30000       760
# 20000       741
# 10000       240
# Name: odometer_km, dtype: int64

# %% [markdown]
# More the odometer's value - more frequently it is found.

# %% [markdown]
# I will aggregate these values in 3 groups based on the odometer's value.

# %%
most_km = autos[autos['odometer_km'] >= 150000]
med_km = autos[(autos['odometer_km'] < 150000) & (autos['odometer_km'] > 50000)]
les_km = autos[autos['odometer_km'] <= 50000]

# %%
most_km
# Out:
#        date_crawled                                               name  \
# 0          20160326                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1          20160404         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 4          20160401  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5          20160321  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6          20160320  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7          20160316                               Golf_IV_1.9_TDI_90PS
# 8          20160322                                         Seat_Arosa
# 9          20160316          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 11         20160316                         Mercedes_A140_Motorschaden
# 13         20160323                                 Audi_A3_1.6_tuning
# 14         20160323  Renault_Clio_3__Dynamique_1.2__16_V;_viele_Ver...
# 16         20160316                                Opel_Vectra_B_Kombi
# ...

# %%
price_most_km = most_km['price_usd'].mean()
price_med_km = med_km['price_usd'].mean()
price_les_km = les_km['price_usd'].mean()

# %%
price_most_km
# Out:
# 3767.765806794761

# %%
price_med_km
# Out:
# 8242.48650851879

# %%
price_les_km
# Out:
# 14880.663101604277

# %% [markdown]
# It is not hard to see, that there is a strong inverse correlation between the odometer's value and the price.
# The more is odometer's value, the less is the price.

# %% [markdown]
# Now let's see how much cheaper are cars with damage than their non-damaged counterparts.

# %% [markdown]
# For this task I will aggregate cars into 2 groups : damaged and non-damaged cars. There are autos with a nan value, I will not count them at all.

# %%
damaged = autos[autos['unrepaired_damage'] == 'yes']
non_damaged = autos[autos['unrepaired_damage'] == 'none']

# %%
damaged_price = damaged['price_usd'].mean()
non_damaged_price = non_damaged['price_usd'].mean()

# %%
damaged_price
# Out:
# 2222.3098808998675

# %%
non_damaged_price
# Out:
# 7153.68978771214

# %% [markdown]
# So, in average cars that have none unrepaired damage cost 3-4 times more than damaged cars.
